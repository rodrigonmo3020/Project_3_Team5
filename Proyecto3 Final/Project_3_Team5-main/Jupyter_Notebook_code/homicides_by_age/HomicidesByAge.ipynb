# %%
import pandas as pd 
from matplotlib import pyplot as plt
from pymongo import MongoClient

# %%
data = pd.read_csv('/Users/geyne/Desktop/global-master-2/Project_3_Team5-main/data_sets/homicides_by_age/EDADESNew.csv',encoding='cp1252')
data
# Out:
#       Year   Total  less than 1 year  1-4 years  5-9 years  10-14 years  \
# 0   1990.0  14,493             143.0      181.0      180.0        275.0
# 1   1991.0  15,128             143.0      209.0      185.0        290.0
# 2   1992.0  16,594             122.0      204.0      150.0        265.0
# 3   1993.0  16,040             112.0      189.0      145.0        265.0
# 4   1994.0  15,839             115.0      192.0      138.0        254.0
# 5   1995.0  15,612             140.0      149.0      123.0        249.0
# 6   1996.0  14,505             129.0      169.0      126.0        213.0
# 7   1997.0  13,552             109.0      126.0      103.0        209.0
# 8   1998.0  13,656              81.0      137.0      127.0        233.0
# 9   1999.0  12,249              98.0      138.0      113.0        219.0
# 10  2000.0  10,737              79.0      108.0       93.0        197.0
# 11  2001.0  10,285              80.0      120.0       99.0        198.0
# ...

# %%
data = data.drop(columns=['Unnamed: 22'])
data
# Out:
#       Year   Total  less than 1 year  1-4 years  5-9 years  10-14 years  \
# 0   1990.0  14,493             143.0      181.0      180.0        275.0
# 1   1991.0  15,128             143.0      209.0      185.0        290.0
# 2   1992.0  16,594             122.0      204.0      150.0        265.0
# 3   1993.0  16,040             112.0      189.0      145.0        265.0
# 4   1994.0  15,839             115.0      192.0      138.0        254.0
# 5   1995.0  15,612             140.0      149.0      123.0        249.0
# 6   1996.0  14,505             129.0      169.0      126.0        213.0
# 7   1997.0  13,552             109.0      126.0      103.0        209.0
# 8   1998.0  13,656              81.0      137.0      127.0        233.0
# 9   1999.0  12,249              98.0      138.0      113.0        219.0
# 10  2000.0  10,737              79.0      108.0       93.0        197.0
# 11  2001.0  10,285              80.0      120.0       99.0        198.0
# ...

# %%
data = data.dropna()
data
# Out:
# Empty DataFrame
# Columns: [Year, Total, less than 1 year, 1-4 years, 5-9 years, 10-14 years, 15-19 years, 20-24 years, 25-29 years, 30-34 years, 35-39 years, 40-44 years, 45-49 years, 50-54 years, 55-59 years, 60-64 years, 65-69 years, 70-74 years, 75-79 years, 80-84 years, 85 years y m‡s, No especificado, Unnamed: 22]
# Index: []
#
# [0 rows x 23 columns]

# %%
columns = list(data.columns)
columns
# Out:
# ['Year',
#  'Total',
#  'less than 1 year',
#  '1-4 years',
#  '5-9 years',
#  '10-14 years',
#  '15-19 years',
#  '20-24 years',
#  '25-29 years',
#  '30-34 years',
#  '35-39 years',
#  '40-44 years',
#  '45-49 years',
#  '50-54 years',
#  '55-59 years',
#  '60-64 years',
#  '65-69 years',
#  '70-74 years',
#  '75-79 years',
#  '80-84 years',
#  '85 years y m‡s',
#  'No especificado']

# %%
#turning data into the correct dtype
data[columns] = data[columns].replace({',':''}, regex = True)
data[columns] = data[columns].astype('int')
data
# Out:
# /var/folders/fk/cvrcy451067_965x_wm3fkwc0000gn/T/ipykernel_93903/2752741138.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[columns] = data[columns].replace({',':''}, regex = True)
# /var/folders/fk/cvrcy451067_965x_wm3fkwc0000gn/T/ipykernel_93903/2752741138.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[columns] = data[columns].astype('int')
#     Year  Total  less than 1 year  1-4 years  5-9 years  10-14 years  \
# ...

# %%
data = data.drop(columns=['No especificado'])
data
# Out:
#     Year  Total  less than 1 year  1-4 years  5-9 years  10-14 years  \
# 0   1990  14493               143        181        180          275
# 1   1991  15128               143        209        185          290
# 2   1992  16594               122        204        150          265
# 3   1993  16040               112        189        145          265
# 4   1994  15839               115        192        138          254
# 5   1995  15612               140        149        123          249
# 6   1996  14505               129        169        126          213
# 7   1997  13552               109        126        103          209
# 8   1998  13656                81        137        127          233
# 9   1999  12249                98        138        113          219
# 10  2000  10737                79        108         93          197
# 11  2001  10285                80        120         99          198
# 12  2002  10088                83        114         69          164
# ...

# %%
df1 = data[data['Year'] > 2017]
df1 = df1.reset_index()
df1
# Out:
#    index  Year  Total  less than 1 year  1-4 years  5-9 years  10-14 years  \
# 0     28  2018  36685                78        104         92          193
# 1     29  2019  36661                72        103         83          203
# 2     30  2020  36773                55         97         92          212
# 3     31  2021  35700                61         73         89          220
# 4     32  2022  33287                64         71         78          199
#
#    15-19 years  20-24 years  25-29 years  ...  40-44 years  45-49 years  \
# 0         2562         5069         5649  ...         3745         2686
# 1         2452         5194         5956  ...         3693         2756
# 2         2362         5083         5650  ...         3529         2627
# 3         2290         4947         5358  ...         3421         2625
# 4         2274         4259         4912  ...         3218         2467
#
#    50-54 years  55-59 years  60-64 years  65-69 years  70-74 years  \
# ...

# %%
df1 = df1.drop(columns=['index'])

# %%
df1
# Out:
#    Year  Total  less than 1 year  1-4 years  5-9 years  10-14 years  \
# 0  2018  36685                78        104         92          193
# 1  2019  36661                72        103         83          203
# 2  2020  36773                55         97         92          212
# 3  2021  35700                61         73         89          220
# 4  2022  33287                64         71         78          199
#
#    15-19 years  20-24 years  25-29 years  30-34 years  ...  40-44 years  \
# 0         2562         5069         5649         5058  ...         3745
# 1         2452         5194         5956         5327  ...         3693
# 2         2362         5083         5650         4969  ...         3529
# 3         2290         4947         5358         4997  ...         3421
# 4         2274         4259         4912         4583  ...         3218
#
#    45-49 years  50-54 years  55-59 years  60-64 years  65-69 years  \
# ...

# %%
df1.to_csv('./newDataAge.csv')

# %%
df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df1
#
# NameError: name 'df1' is not defined
