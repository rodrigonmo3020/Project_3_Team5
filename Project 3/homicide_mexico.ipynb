# %%
from pymongo import MongoClient
from pprint import pprint
import csv
import pandas as pd
import numpy as numpy
import matplotlib.pyplot as plt

# %%
mongo= MongoClient()
db1= mongo.Homicidio_edad
list(db1.homicide_age.find())
# Out:
# [{'_id': ObjectId('65a9bc8960e1d169d3d513d0'),
#   'año': 2018,
#   'edad': ' Menores de 1 año',
#   'total_edad': 78},
#  {'_id': ObjectId('65a9bc8960e1d169d3d513d1'),
#   'año': 2018,
#   'edad': ' 1-4 años',
#   'total_edad': 104},
#  {'_id': ObjectId('65a9bc8960e1d169d3d513d2'),
#   'año': 2018,
#   'edad': ' 5-9 años',
#   'total_edad': 92},
#  {'_id': ObjectId('65a9bc8960e1d169d3d513d3'),
#   'año': 2018,
#   'edad': ' 10-14 años',
#   'total_edad': 193},
#  {'_id': ObjectId('65a9bc8960e1d169d3d513d4'),
#   'año': 2018,
#   'edad': ' 15-19 años',
#   'total_edad': 2562},
#  {'_id': ObjectId('65a9bc8960e1d169d3d513d5'),
#   'año': 2018,
#   'edad': ' 20-24 años',
#   'total_edad': 5069},
#  {'_id': ObjectId('65a9bc8960e1d169d3d513d6'),
#   'año': 2018,
#   'edad': ' 25-29 años',
#   'total_edad': 5649},
#  {'_id': ObjectId('65a9bc8960e1d169d3d513d7'),
#   'año': 2018,
#   'edad': ' 30-34 años',
#   'total_edad': 5058},
#  {'_id': ObjectId('65a9bc8960e1d169d3d513d8'),
# ...

# %%
homicide_age= db1['homicide_age']
homicide_age
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'Homicidio_edad'), 'homicide_age')

# %%
db2= mongo.dataOfStudyGrades
list(db2.dataOfStudyGrades.find())
# Out:
# []

# %%
homicide_study_grade=db2['dataOfStudyGrades']
homicide_study_grade
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'dataOfStudyGrades'), 'dataOfStudyGrades')

# %%
db3= mongo.states_info
list(db3.states_info.find())
# Out:
# []

# %%
states_info= db3['states_info']
states_info
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'states_info'), 'states_info')
